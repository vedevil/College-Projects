# %%
from mat4py import loadmat
import numpy as np
data = loadmat('data.mat')
vowel_map={0:'a',1:'e',2:'i',3:'u'}
l=list(data['vowels'][3]['training'])

# %%
l
# Out:
# [[469.8393444324429, 1090.6677788209986],
#  [418.0553311193224, 1208.321353585798],
#  [383.7498091250061, 1028.2666641052845],
#  [369.869941655002, 812.8402459741477],
#  [462.9281268518091, 920.035745332336],
#  [363.26078134781636, 806.4297896730369],
#  [554.9171377379115, 1226.130590783212],
#  [450.14077664625216, 945.8706225174774],
#  [505.2140739310166, 1047.798372970103],
#  [548.2354734919911, 1339.1730566240092],
#  [558.0574473261103, 1066.2747388289076],
#  [359.13664523935773, 840.0000189315633],
#  [519.0782989098099, 1190.1203015345177],
#  [504.2317483752515, 1144.4352083417525],
#  [367.545768267527, 990.7926264177547],
#  [496.22227426418993, 1042.6960114219128],
#  [560.627098501347, 1222.0483762107149],
#  [540.1852521505609, 1216.0989986596244],
#  [484.1725165354387, 1165.37044001088],
#  [555.166909373209, 1066.8751300117492],
#  [377.230184406149, 956.3344955172013],
#  [320.725610702652, 1076.9813277899075],
#  [515.2638206707594, 865.6722357069536],
# ...

# %%
l=np.array(l)
x=l[:,0]
y=l[:,1]

# %%
cov=np.cov(x,y)

# %%
cov
# Out:
# array([[ 9965.05431832,  8510.36263691],
#        [ 8510.36263691, 17397.22458866]])

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()
